# %%
# %%bash
# mkdir lab4
# cd lab4
# git clone https://github.com/sophiajwchoi/Lab4-Adding-Discovery-to-Chatbot.git
# Out:
# Cloning into 'Lab4-Adding-Discovery-to-Chatbot'...

# %%
# %%bash
# cd /resources/lab4/Lab4-Adding-Discovery-to-Chatbot
# export npm_config_loglevel=silent
# conda config --set notify_outdated_conda false
# conda install nodejs -y
# rm -f ~/.npmrc
# npm install
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# audited 130 packages in 12.361s
# found 4 vulnerabilities (2 low, 2 high)
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# %%bash
# ibmcloud config --check-version=false
# ibmcloud login --no-region
# <IBM ACCOUNT>
# <IBM ACC PASSWORD>
# Out:
# API endpoint: https://cloud.ibm.com
#
# Email> swagat_ug@cse.nits.ac.in
#
# Password>
# Authenticating...
# OK
#
# Targeted account Swagat Shubham Bhuyan's Account (6577bb2dbf9a41a0a6d66ee0a1a52649)
#
#
# API endpoint:      https://cloud.ibm.com
# Region:
# User:              swagat_ug@cse.nits.ac.in
# Account:           Swagat Shubham Bhuyan's Account (6577bb2dbf9a41a0a6d66ee0a1a52649)
# Resource group:    No resource group targeted, use 'ibmcloud target -g RESOURCE_GROUP'
# CF API endpoint:
# Org:
# Space:

# %%
# %%bash
# ibmcloud account orgs
# Out:
# Getting orgs in all regions as swagat_ug@cse.nits.ac.in...
# Retrieving current account...
# OK
#
# Name                       Region   Account owner              Account ID                         Status
# swagat_ug@cse.nits.ac.in   eu-gb    swagat_ug@cse.nits.ac.in   6577bb2dbf9a41a0a6d66ee0a1a52649   active

# %%
# %%bash
# ibmcloud target --cf-api 'https://api.eu-gb.cf.cloud.ibm.com' -r eu-gb -o swagat_ug@cse.nits.ac.in
# ibmcloud account space-create 'lab4_'
# Out:
# Switched to region eu-gb
#
# Targeted Cloud Foundry (https://api.eu-gb.cf.cloud.ibm.com)
#
# Targeted org swagat_ug@cse.nits.ac.in
#
#
#
# API endpoint:      https://cloud.ibm.com
# Region:            eu-gb
# User:              swagat_ug@cse.nits.ac.in
# Account:           Swagat Shubham Bhuyan's Account (6577bb2dbf9a41a0a6d66ee0a1a52649)
# Resource group:    No resource group targeted, use 'ibmcloud target -g RESOURCE_GROUP'
# CF API endpoint:   https://api.eu-gb.cf.cloud.ibm.com (API version: 2.152.0)
# Org:               swagat_ug@cse.nits.ac.in
# Space:
# Creating space lab4_ in org swagat_ug@cse.nits.ac.in as swagat_ug@cse.nits.ac.in...
# OK
# Assigning role SpaceManager to user swagat_ug@cse.nits.ac.in in org swagat_ug@cse.nits.ac.in / space lab4_ as swagat_ug@cse.nits.ac.in...
# OK
# Assigning role SpaceDeveloper to user swagat_ug@cse.nits.ac.in in org swagat_ug@cse.nits.ac.in / space lab4_ as swagat_ug@cse.nits.ac.in...
# OK

# %%
# %%bash
# cd /resources/lab4/Lab4-Adding-Discovery-to-Chatbot
# ibmcloud target -s lab4_
# ibmcloud plugin install cloud-functions -f
# export npm_config_loglevel=silent
# npm install -g serverless@1.51.0
# ibmcloud fn --apihost eu-gb.functions.cloud.ibm.com
# ibmcloud fn list --apihost eu-gb.functions.cloud.ibm.com
# serverless deploy
# Out:
# Targeted space lab4_
#
#
#
# API endpoint:      https://cloud.ibm.com
# Region:            eu-gb
# User:              swagat_ug@cse.nits.ac.in
# Account:           Swagat Shubham Bhuyan's Account (6577bb2dbf9a41a0a6d66ee0a1a52649)
# Resource group:    No resource group targeted, use 'ibmcloud target -g RESOURCE_GROUP'
# CF API endpoint:   https://api.eu-gb.cf.cloud.ibm.com (API version: 2.152.0)
# Org:               swagat_ug@cse.nits.ac.in
# Space:             lab4_
# Looking up 'cloud-functions' from repository 'IBM Cloud'...
# Plug-in 'cloud-functions/wsk/functions/fn 1.0.45' found in repository 'IBM Cloud'
# Attempting to download the binary file...
#  14.36 MiB / 14.36 MiB  100.00% 0s
# 15052434 bytes downloaded
# Installing binary...
# OK
# Plug-in 'cloud-functions 1.0.45' was successfully installed into /home/jupyterlab/.bluemix/plugins/cloud-functions. Use 'ibmcloud plugin show cloud-functions' to show its details.
# /home/jupyterlab/conda/envs/python/bin/serverless -> /home/jupyterlab/conda/envs/python/lib/node_modules/serverless/bin/serverless.js
# /home/jupyterlab/conda/envs/python/bin/slss -> /home/jupyterlab/conda/envs/python/lib/node_modules/serverless/bin/serverless.js
# /home/jupyterlab/conda/envs/python/bin/sls -> /home/jupyterlab/conda/envs/python/lib/node_modules/serverless/bin/serverless.js
#  +--------------------------------------------------+
#  |                                                  |
#  |  Serverless Framework successfully installed!    |
#  |  To start your first project, run “serverless”.  |
#  |                                                  |
#  +--------------------------------------------------+
#
# + serverless@1.51.0
# added 521 packages from 339 contributors in 83.798s
# Manage Cloud Functions
# Usage:
#   wsk [command]
#
# Available Commands:
#   action      work with actions
#   activation  work with activations
#   package     work with packages
#   rule        work with rules
#   trigger     work with triggers
#   sdk         work with the sdk
#   list        list entities in the current namespace
#   api         work with APIs
#   service     Bind and unbind service credentials to an action or package.
#   deploy      Deploy a collection of packages, actions, triggers and rules with a deployment manifest file
#   undeploy    Undeploy a previously deployed collection of packages, actions, triggers and rules
#   property    work with whisk properties
#   namespace   Work with IAM-based and Cloud Foundry-based namespaces.
#
#
# Flags:
#       --apihost HOST         whisk API HOST
#       --apiversion VERSION   whisk API VERSION
#   -u, --auth KEY             authorization KEY
#   -d, --debug                debug level output
#   -i, --insecure             bypass certificate checking
#   -v, --verbose              verbose output
#
# Use "wsk [command] --help" for more information about a command.
# Entities in namespace: default
# packages
# actions
# triggers
# rules
# Serverless: Packaging service...
# Serverless: Excluding development dependencies...
# Serverless: Compiling Functions...
# Serverless: Compiling Packages...
# Serverless: Compiling API Gateway definitions...
# Serverless: Compiling Rules...
# Serverless: Compiling Triggers & Feeds...
# Serverless: Compiling Service Bindings...
# Serverless: Deploying Packages...
# Serverless: Deploying Functions...
# Serverless: Deployment successful!
#
# Service Information
# platform:	eu-gb.functions.cloud.ibm.com
# namespace:	_
# service:	lab-4
#
# packages:
# lab4
#
# actions:
# lab4/connectDiscovery
#
# triggers:
# **no triggers deployed**
#
# rules:
# **no rules deployed**
#
# endpoints (api-gw):
# **no routes deployed**
#
# endpoints (web actions):
# **no web actions deployed**
# [tabtab] Adding source line to load /home/jupyterlab/conda/envs/python/lib/node_modules/serverless/node_modules/tabtab/.completions/serverless.bash
# in /home/jupyterlab/.bashrc
#
#
# [tabtab] Adding source line to load /home/jupyterlab/conda/envs/python/lib/node_modules/serverless/node_modules/tabtab/.completions/sls.bash
# in /home/jupyterlab/.bashrc
#
#
# [tabtab] Adding source line to load /home/jupyterlab/conda/envs/python/lib/node_modules/serverless/node_modules/tabtab/.completions/slss.bash
# in /home/jupyterlab/.bashrc

# %%
# !ibmcloud fn list
# Out:
# Entities in namespace: default
# packages
# /swagat_ug@cse.nits.ac.in_lab4_/lab4                                   private
# actions
# /swagat_ug@cse.nits.ac.in_lab4_/lab4/connectDiscovery                  private nodejs:10
# triggers
# rules
